# %%
import pandas as pd
import numpy as np
import mibian
import math
from scipy.stats import norm
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
#Calls = pd.read_csv('nifty_311221_190122_1min_calls.csv')
Calls = pd.read_csv('nifty_311221_190122_1min_calls_py_vollib.csv')

# %% [markdown]
# ### Training Model

# %%
def pre_train_process(df,startDate,windowLength,isNormalized,moneyness):
    tmp = df.copy()
    tmp = tmp[np.abs(tmp['delta'] - moneyness) <= 0.025]
    start = startDate
    train_start_index = tmp[tmp['date'] == start].index[0]
    train_window_length = windowLength
    train_end_index = train_start_index+train_window_length
    tmp = tmp.iloc[train_start_index:train_end_index]
    if(isNormalized==True):
    ## normalize the option price change and future price change
        tmp['opt_price_chg'] = tmp['opt_price'].diff()
        tmp['fut_price_chg'] = tmp['fut_price'].diff()
        tmp = tmp[tmp['fut_price_chg']!=0]
    else:
        tmp['opt_price_chg'] = tmp['opt_price'] / tmp['opt_price'].shift()
        tmp['fut_price_chg'] = tmp['fut_price'] / tmp['fut_price'].shift()
        tmp = tmp[tmp['fut_price_chg']!=1]
    tmp = tmp[['ts','opt_price_chg','fut_price_chg','delta','vega','days_to_expiry','fut_price']]
    tmp.reset_index(drop=True,inplace=True)
    train_set = pd.DataFrame()
    train_set['y'] = (tmp['opt_price_chg'] - tmp['delta']*tmp['fut_price_chg'])*np.sqrt(tmp['days_to_expiry'])/tmp['vega']*tmp['fut_price']/tmp['fut_price_chg']
    train_set['x1'] = tmp['delta']
    train_set['x2'] = tmp['delta']**2
    train_set.drop(index=0,inplace=True)
    return train_set

# %%
def train_model(train_set):
    x = sm.add_constant(train_set.iloc[:,1:])
    y = train_set['y']
    model = sm.OLS(y,x)
    result = model.fit()
    return result

# %%
def predict_MV_delta(df,startDate,windowLength,result):
    tmp = df.copy()
    test_start_index = tmp[tmp['date'] == startDate].index[0]
    test_window_length = windowLength
    test_end_index = test_start_index + test_window_length
    tmp = tmp.iloc[test_start_index:test_end_index]
    tmp = tmp[['ts','delta','vega','days_to_expiry','fut_price']]
    b0 = result.params[0]
    b1 = result.params[1]
    b2 = result.params[2]
    tmp['y_hat'] = b0+b1*tmp['delta']+b2*tmp['delta']**2
    tmp['MV_delta'] = tmp['delta']+tmp['vega']/tmp['fut_price']/np.sqrt(tmp['days_to_expiry'])*(b0+b1*tmp['delta']+b2*tmp['delta']**2)
    return tmp

# %% [markdown]
# ### Read in data

# %% [markdown]
# ## NOTE! when select df, I should just choose one contract to continue to do the research!!!

# %%
Calls = pd.read_csv('nifty_311221_190122_1min_calls_py_vollib.csv')
Calls['opt_symbol'].unique().size
# Out:
# 79

# %%
Calls[Calls['opt_symbol']=='NIFTY22JAN17450CE']
# Out:
#         Unnamed: 0                       date  opt_price  volume_x  \
# 0                0  2021-12-31 09:15:00+05:30     231.50       0.0
# 59             107  2021-12-31 09:16:00+05:30     235.00     550.0
# 134            241  2021-12-31 09:17:00+05:30     237.85    5450.0
# 208            372  2021-12-31 09:18:00+05:30     237.65     200.0
# 268            484  2021-12-31 09:19:00+05:30     238.10    3050.0
# ...            ...                        ...        ...       ...
# 320222      683091  2022-01-19 15:27:00+05:30     544.15       0.0
# 320243      683141  2022-01-19 15:28:00+05:30     544.15       0.0
# 320336      683357  2022-01-19 15:29:00+05:30     544.15       0.0
# 320372      683436  2022-01-19 15:30:00+05:30     544.15       0.0
# 320424      683546  2022-01-19 16:19:00+05:30     544.15       0.0
#
#                opt_symbol  fut_price  volume_y     fut_symbol   name  \
# 0       NIFTY22JAN17450CE   17311.00  174100.0  NIFTY22JANFUT  NIFTY
# 59      NIFTY22JAN17450CE   17332.10  191750.0  NIFTY22JANFUT  NIFTY
# 134     NIFTY22JAN17450CE   17330.70   83200.0  NIFTY22JANFUT  NIFTY
# 208     NIFTY22JAN17450CE   17338.25   80850.0  NIFTY22JANFUT  NIFTY
# 268     NIFTY22JAN17450CE   17335.00   64800.0  NIFTY22JANFUT  NIFTY
# ...                   ...        ...       ...            ...    ...
# 320222  NIFTY22JAN17450CE   17974.25   64400.0  NIFTY22JANFUT  NIFTY
# 320243  NIFTY22JAN17450CE   17976.00   56600.0  NIFTY22JANFUT  NIFTY
# 320336  NIFTY22JAN17450CE   17975.50   38600.0  NIFTY22JANFUT  NIFTY
# 320372  NIFTY22JAN17450CE   17975.50     200.0  NIFTY22JANFUT  NIFTY
# 320424  NIFTY22JAN17450CE   17975.50       0.0  NIFTY22JANFUT  NIFTY
#
#                      expiry   strike instrument_type                   ts  \
# 0       2022-01-27 15:30:30  17450.0              CE  2021-12-31 09:15:00
# 59      2022-01-27 15:30:30  17450.0              CE  2021-12-31 09:16:00
# 134     2022-01-27 15:30:30  17450.0              CE  2021-12-31 09:17:00
# 208     2022-01-27 15:30:30  17450.0              CE  2021-12-31 09:18:00
# 268     2022-01-27 15:30:30  17450.0              CE  2021-12-31 09:19:00
# ...                     ...      ...             ...                  ...
# 320222  2022-01-27 15:30:30  17450.0              CE  2022-01-19 15:27:00
# 320243  2022-01-27 15:30:30  17450.0              CE  2022-01-19 15:28:00
# 320336  2022-01-27 15:30:30  17450.0              CE  2022-01-19 15:29:00
# 320372  2022-01-27 15:30:30  17450.0              CE  2022-01-19 15:30:00
# 320424  2022-01-27 15:30:30  17450.0              CE  2022-01-19 16:19:00
#
#         days_to_expiry        IV     delta        vega
# 0            27.260764  0.129723  0.434036  341.824831
# 59           27.260069  0.127160  0.443862  342.803555
# 134          27.259375  0.128703  0.443975  342.324881
# 208          27.258681  0.127123  0.447192  342.869310
# 268          27.257986  0.127968  0.445887  342.580852
# ...                ...       ...       ...         ...
# 320222        8.002431  0.130574  0.900388  195.858694
# 320243        8.001736  0.127700  0.905992  195.972441
# 320336        8.001042  0.128543  0.904365  195.928992
# 320372        8.000347  0.128548  0.904365  195.920489
# 320424        7.966319  0.128823  0.904365  195.503392
#
# [4811 rows x 17 columns]

# %%
tmp = Calls[np.abs(Calls['delta'] - 0.5) <= 0.05].reset_index()
tmp = tmp[['date','opt_price','fut_price','volume_y','strike','days_to_expiry','IV','delta','vega']]
tmp
# Out:
#                             date  opt_price  fut_price  volume_y   strike  \
# 0      2021-12-31 09:15:00+05:30     307.30    17311.0  174100.0  17300.0
# 1      2021-12-31 09:15:00+05:30     254.40    17311.0  174100.0  17400.0
# 2      2021-12-31 09:15:00+05:30     337.50    17311.0  174100.0  17250.0
# 3      2021-12-31 09:15:00+05:30     275.55    17311.0  174100.0  17350.0
# 4      2021-12-31 09:16:00+05:30     316.85    17332.1  191750.0  17300.0
# ...                          ...        ...        ...       ...      ...
